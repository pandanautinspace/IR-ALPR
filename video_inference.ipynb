# %%
import torch
from torchvision.transforms import transforms
from PIL import Image, ImageDraw, ImageFont
import cv2
import numpy as np
import json
from ultralytics import YOLO
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import os
# Out:
# c:\Users\panda\miniconda3\envs\ipx_torch\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: 'Could not find module 'C:\Users\panda\miniconda3\envs\ipx_torch\Lib\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
base_dir = "."

# %%
dataset_dir = "./test/"

# %%
# Load OCR Model
class CNN(torch.nn.Module):
    def __init__(self, in_size=(200, 50, 1), conv_out_1=32, conv_kern_1=3, conv_out_2=64,
                 conv_kern_2=3, fc1_out=64, lstm1_out=128, lstm2_out=64, fc2_out=38):
        super(CNN, self).__init__()
        w, h, c = in_size
        self.conv1 = torch.nn.Conv2d(c, conv_out_1, kernel_size=conv_kern_1, padding="same")
        self.conv2 = torch.nn.Conv2d(conv_out_1, conv_out_2, kernel_size=conv_kern_2, padding="same")
        self.fc1 = torch.nn.Linear(conv_out_2, fc1_out)
        self.lstm1 = torch.nn.LSTM(fc1_out * (h // 4), lstm1_out, bidirectional=True, batch_first=True)
        self.lstm2 = torch.nn.LSTM(lstm1_out * 2, lstm2_out, bidirectional=True, batch_first=True)
        self.fc2 = torch.nn.Linear(lstm2_out * 2, fc2_out)

    def forward(self, x):
        batch_size, c, h, w = x.shape
        x = torch.relu(self.conv1(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = torch.relu(self.conv2(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = x.permute(0, 3, 2, 1)
        x = torch.relu(self.fc1(x))
        x = torch.dropout(x, p=0.2, train=False)
        x = x.reshape(batch_size, w // 4, -1)
        x, _ = self.lstm1(x)
        x = torch.dropout(x, p=0.25, train=False)
        x, _ = self.lstm2(x)
        x = torch.dropout(x, p=0.25, train=False)
        x = torch.log_softmax(self.fc2(x), dim=-1)
        return x.permute(1, 0, 2)

# %%
# Load OCR Model and Classes
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# weights_path = "path_to_your_saved_weights.pth"  
# ocr_model.load_state_dict(torch.load(weights_path))
# ocr_model = torch.load("/home/infres/lotfi-23/training/model_last.pth")
ocr_model = torch.load(base_dir + "/best-ocr-model.pt", map_location=torch.device('cpu'))
ocr_model = ocr_model.to(device)
ocr_model.eval()

with open(base_dir + "/classes.json", "r") as f:
    classes = json.load(f)

# Define OCR transforms
ocr_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.ConvertImageDtype(torch.float32)
])

# Decode OCR predictions
def decode_predictions(predictions, classes):
    pred_str = ''.join([classes[c - 1] if c != 0 else '_' for c in predictions])
    pred_str = ''.join(ch for i, ch in enumerate(pred_str) if ch != '_' and (i == 0 or ch != pred_str[i - 1]))
    return pred_str

# Load YOLO Model
yolo_model = YOLO(base_dir + "/yolo-best.pt")

# %%
import PILasOPENCV as CImage
import PILasOPENCV as CImageDraw
import PILasOPENCV as CImageFont

font = CImageFont.truetype("arial.ttf", 24)
np.bool = np.bool_ #library uses deprectated alias

# # Perform inference and visualize results
persian_to_equivalent = {
    "ب": "B",
    "ج": "J",
    "د": "D",
    "س": "S",
    "ص": "Ṣ",
    "ط": "Ṭ",
    "ق": "Q",
    "ل": "L",
    "م": "M",
    "و": "V",
    "ه": "H",
    "ه‍": "H",
    "ن": "N",
    "ی": "Y",
    "الف": "A",
    "پ": "P",
    "ت": "T",
    "ث": "Ṯ",
    "ز": "Z",
    "ژ": "Ž",
    "ش": "Š",
    "ع": "O",
    "ف": "F",
    "ك": "K",
    "گ": "G",
    "۰": "0",
    "۱": "1",
    "۲": "2",
    "۳": "3",
    "۴": "4",
    "۵": "5",
    "۶": "6",
    "۷": "7",
    "۸": "8",
    "۹": "9"
}

pers = {v: k for k,v in persian_to_equivalent.items()}

def detect_and_visualize_cv(image, yolo_model, ocr_model, ocr_transforms, classes, device, next_state, save_path=None, prev_state=None):
    """
    Detect and visualize license plates in an image, showing bounding boxes,
    detected plate text, and confidence scores.
    """

    # Run YOLO detection
    results = yolo_model(image)
    boxes = results[0].boxes

    # if len(boxes) == 0:
    #     #print("No license plates detected.")
    #     return

    # Convert the image to RGB for plt visualization
    # image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    next_state.boxes = []
    next_state.velocities = []
    # next_state.labels = []
    next_state.ages = []

    processed_boxes = []

    def interp(x,px,v):
        return (x + 2 * (px + v // 8)) // 3

    #preprocess boxes
    for box in boxes:
        x_min, y_min, x_max, y_max = map(int, box.xyxy[0].cpu().numpy())
        prev_i = None
        if prev_state is not None:
            for i, p_box in enumerate(prev_state.boxes):
                p_x_min, p_y_min, p_x_max, p_y_max = p_box
                if (p_x_min<=x_min<=p_x_max or p_x_min<=x_max<=p_x_max or x_min<=p_x_min<=x_max or x_min<=p_x_max<=x_max) and (p_y_min<=y_min<=p_y_max or p_y_min<=y_max<=p_y_max or y_min<=p_y_min<=y_max or y_min<=p_y_max<=y_max):
                    prev_i = i
                    break
        if prev_i is not None:
            p_x_min, p_y_min, p_x_max, p_y_max = prev_state.boxes[prev_i]
            vx1, vy1, vx2, vy2 = prev_state.velocities[prev_i]
            x_min = interp(x_min, p_x_min, vx1)
            x_max = interp(x_max, p_x_max, vx2)
            y_min = interp(y_min, p_y_min, vy1)
            y_max = interp(y_max, p_y_max, vy2)
            prev_state.ages[prev_i] = -1
            next_state.velocities.append((x_min - p_x_min, y_min - p_y_min, x_max - p_x_max, y_max - p_y_max))
            next_state.ages.append(0)
        else:
            next_state.velocities.append((0,0,0,0))
            next_state.ages.append(0)
        next_state.boxes.append((x_min, y_min, x_max, y_max))
        processed_boxes.append((x_min, y_min, x_max, y_max, box.conf[0]))

    if prev_state is not None:
        for i, box in enumerate(prev_state.boxes):
            continue
            if 0<=prev_state.ages[i]<1:
                p_x_min, p_y_min, p_x_max, p_y_max = prev_state.boxes[i]
                vx1, vy1, vx2, vy2 = prev_state.velocities[i]
                x_min = interp(p_x_min, p_x_min, vx1)
                x_max = interp(p_x_max, p_x_max, vx2)
                y_min = interp(p_y_min, p_y_min, vy1)
                y_max = interp(p_y_max, p_y_max, vy2)
                next_state.velocities.append((0,0,0,0))
                next_state.ages.append(prev_state.ages[i]+1)
                next_state.boxes.append((x_min, y_min, x_max, y_max))
                processed_boxes.append((x_min, y_min, x_max, y_max, 0))

    print("boxes:", len(processed_boxes))
    for box in processed_boxes:
        # Extract bounding box coordinates
        x_min, y_min, x_max, y_max, conf = box
        if x_min < 0:
            x_min=0
        if x_max >= image.shape[1]:
            x_max = image.shape[1] - 1
        if y_min < 0:
            y_min=0
        if y_max >= image.shape[0]:
            y_max = image.shape[0] - 1
        plate_image = image[y_min:y_max, x_min:x_max]

        # Preprocess plate image for OCR
        try:
            plate_image_pil = Image.fromarray(cv2.cvtColor(plate_image, cv2.COLOR_BGR2RGB)).convert('L')
        except:
            print(x_min, y_min, x_max, y_max, conf)
            plate_image_pil = Image.new("RGB", (1, 1), "black").convert('L')
        plate_image_resized = plate_image_pil.resize((200, 50))
        # plate_image_resized = plate_image_resized.getim()
        plate_tensor = ocr_transforms(plate_image_resized).unsqueeze(0).to(device)

        # Perform OCR
        with torch.no_grad():
            outputs = ocr_model(plate_tensor)
            probabilities = torch.exp(outputs)  # Convert log-softmax to probabilities
            predictions = outputs.argmax(dim=-1).cpu().numpy()[:, 0]
        plate_text = decode_predictions(predictions, classes)
        #print(predictions)
        #print(len(predictions))

        # #print(f"Outputs shape: {outputs.shape}")
        # #print(f"Probabilities range: min={probabilities.min().item()}, max={probabilities.max().item()}")

        # Log character confidences
        # char_confidences = [(classes[c-1], probabilities[0, :, c].max().item()) for c in predictions if c != 0]
        char_confidences1 = []
        for t, c in enumerate(predictions):
            if c != 0 and c <= len(classes):  # Ignore blank index
                char = classes[c - 1]  # Map to the corresponding character
                confidence = probabilities[t, 0, c].item()  # Confidence for this character
                char_confidences1.append((char, confidence))
        
        
        # Map confidences to the final plate text
        char_confidences = []
        prediction_idx = 0  # Pointer for predictions

        for char in plate_text:
            while prediction_idx < len(predictions):
                pred_char_idx = predictions[prediction_idx]
                if pred_char_idx != 0:  # Ignore blanks
                    matched_char = classes[pred_char_idx - 1]
                    if matched_char == char:
                        confidence = probabilities[prediction_idx, 0, pred_char_idx].item()
                        char_confidences.append((char, confidence))
                        prediction_idx += 1
                        break
                prediction_idx += 1

        image = cv2.rectangle(image, (x_min,y_min), (x_max, y_max), (0,0,255), 2)
        plate_text = ''.join([pers[c] for c in plate_text])
        # Add text above the bounding box
        confidence_text = f"{plate_text} ({conf:.2f})"
        # ax.text(x_min, y_min - 15, confidence_text, color='red', fontsize=12,
        #         bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))
        # im.setim(image)
        # draw.text((x_min, y_min - 15), confidence_text, font=font, fill=(255,0,0))
        # image = im.getim()
        mask = CImageFont.getmask(confidence_text, font)
        # img_mask = np.zeros_like(image)
        if y_min - 15 > 0:
            y1,y2,x1,x2 = y_min-15,(y_min-15+mask.shape[0]),x_min,(x_min+mask.shape[1])
        else:
            y1,y2,x1,x2 = y_min-15,(y_min-15+mask.shape[0]),x_min,(x_min+mask.shape[1])
        
        y_amt, x_amt, _ = image[y1:y2,x1:x2].shape
        image[y1:y2,x1:x2] = np.where(mask[:y_amt,:x_amt, None] != 0, (0,0,255), image[y1:y2,x1:x2] // 2)
        cv2.imshow('image', image)
        cv2.waitKey(1)
        # image = cv2.putText(image, confidence_text, (x_min, y_min - 15), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 3, cv2.LINE_AA)

    return image
    # Save or display the result
    # if save_path:
    #     # plt.savefig(save_path, bbox_inches='tight')
    #     #print(f"Image saved at {save_path}")
    # else:
    #     pass #plt.show()


def detect_and_visualize(image_path, yolo_model, ocr_model, ocr_transforms, classes, device, save_path=None):
    """
    Detect and visualize license plates in an image, showing bounding boxes,
    detected plate text, and confidence scores.
    """
    import matplotlib.pyplot as plt
    from matplotlib.patches import Rectangle

    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Could not read image at {image_path}")

    # Run YOLO detection
    results = yolo_model(image)
    boxes = results[0].boxes

    # if len(boxes) == 0:
    #     #print("No license plates detected.")
    #     return

    # Convert the image to RGB for plt visualization
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Initialize a plt figure
    plt.figure(figsize=(12, 8))
    plt.imshow(image_rgb)
    ax = plt.gca()

    for box in boxes:
        # Extract bounding box coordinates
        x_min, y_min, x_max, y_max = map(int, box.xyxy[0].cpu().numpy())
        plate_image = image[y_min:y_max, x_min:x_max]

        # Preprocess plate image for OCR
        plate_image_pil = Image.fromarray(cv2.cvtColor(plate_image, cv2.COLOR_BGR2RGB)).convert('L')
        plate_image_resized = plate_image_pil.resize((200, 50))
        plate_tensor = ocr_transforms(plate_image_resized).unsqueeze(0).to(device)

        # Perform OCR
        with torch.no_grad():
            outputs = ocr_model(plate_tensor)
            probabilities = torch.exp(outputs)  # Convert log-softmax to probabilities
            predictions = outputs.argmax(dim=-1).cpu().numpy()[:, 0]
        plate_text = decode_predictions(predictions, classes)
        #print(predictions)
        #print(len(predictions))

        # #print(f"Outputs shape: {outputs.shape}")
        # #print(f"Probabilities range: min={probabilities.min().item()}, max={probabilities.max().item()}")

        # Log character confidences
        # char_confidences = [(classes[c-1], probabilities[0, :, c].max().item()) for c in predictions if c != 0]
        char_confidences1 = []
        for t, c in enumerate(predictions):
            if c != 0 and c <= len(classes):  # Ignore blank index
                char = classes[c - 1]  # Map to the corresponding character
                confidence = probabilities[t, 0, c].item()  # Confidence for this character
                char_confidences1.append((char, confidence))
        
        
        # Map confidences to the final plate text
        char_confidences = []
        prediction_idx = 0  # Pointer for predictions

        for char in plate_text:
            while prediction_idx < len(predictions):
                pred_char_idx = predictions[prediction_idx]
                if pred_char_idx != 0:  # Ignore blanks
                    matched_char = classes[pred_char_idx - 1]
                    if matched_char == char:
                        confidence = probabilities[prediction_idx, 0, pred_char_idx].item()
                        char_confidences.append((char, confidence))
                        prediction_idx += 1
                        break
                prediction_idx += 1


        # char_confidences = {classes[c]: probabilities[t, 0, c].item()
        #             for t, c in enumerate(predictions) if c <= len(classes)}
        # char_confidences = []
        # for t, c in enumerate(predictions):
        #     if c != 0 and c <= len(classes):  # Ignore blank and invalid indices
        #         char_confidences.append({
        #             'char': classes[c - 1],
        #             'confidence': probabilities[t, 0, c].item()
        #         })
        #print(f'Bounding Box Confidence: {box.conf[0]:.2f}')
        #print(f"Plate text: {plate_text}")
        # #print(f"Character confidences: {char_confidences1}")
        #print(f"Final Character confidences: {char_confidences}")

        # Draw bounding box
        ax.add_patch(Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                               linewidth=2, edgecolor='red', facecolor='none'))

        # Add text above the bounding box
        confidence_text = f"{plate_text} ({box.conf[0]:.2f})"
        ax.text(x_min, y_min - 15, confidence_text, color='red', fontsize=12,
                bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))

    # Save or display the result
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')
        plt.close()
        #print(f"Image saved at {save_path}")
    else:
        pass #plt.show()

# %%
# # Example Usage
# image_path = "/Users/panda/IR-ALPR/iran-dashcam-already.mp4"  # Replace with the path to your test image
# save_path = "output_with_bounding_boxes1.jpg"  # Replace or set to None to only display
# detect_and_visualize(image_path, yolo_model, ocr_model, ocr_transforms, classes, device)

# %%
class MyState:
    def __init__(self):
        self.boxes = []
        self.velocities = []
        self.ages = []

# %%
import io
import numpy as np


def process_input(input_path, yolo_model, ocr_model, ocr_transforms, classes, device, output_path=None):
    """
    Wrapper function to handle both images and videos.
    Args:
        input_path (str): Path to the input file (image or video).
        yolo_model: YOLO model for license plate detection.
        ocr_model: OCR model for character recognition.
        ocr_transforms: Transformations for the OCR model.
        classes: Character classes used in OCR.
        device: Torch device for inference.
        output_path (str): Path to save the output (optional).
    """
    if os.path.isfile(input_path):
        # Determine if the input is an image or video
        ext = os.path.splitext(input_path)[-1].lower()
        if ext in ['.jpg', '.jpeg', '.png', '.bmp']:
            # Handle image
            #print(f"Processing image: {input_path}")
            detect_and_visualize(input_path, yolo_model, ocr_model, ocr_transforms, classes, device, save_path=output_path)
        elif ext in ['.mp4', '.avi', '.mov', '.mkv']:
            # Handle video
            #print(f"Processing video: {input_path}")
            process_video(input_path, yolo_model, ocr_model, ocr_transforms, classes, device, output_video_path=output_path)
        else:
            print(f"Unsupported file type: {ext}")
    else:
        print(f"File not found: {input_path}")

def process_video(video_path, yolo_model, ocr_model, ocr_transforms, classes, device, output_video_path=None):
    """
    Process video input using the existing detect_and_visualize pipeline for each frame.
    """
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError(f"Could not open video {video_path}")
    
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    if output_video_path:
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    frame_count = 0
    try:
        prev_state = None
        state = MyState()
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            # Save the frame temporarily to pass it to detect_and_visualize
            # temp_image_path = f"temp_frame_{frame_count}.jpg"
            # cv2.imwrite(temp_image_path, frame)

            # Run detection and visualization
            # temp_output_path = f"temp_output_frame_{frame_count}.jpg" if output_video_path else None
            # temp_buf = io.BytesIO() if output_video_path else None
            frame = detect_and_visualize_cv(frame, yolo_model, ocr_model, ocr_transforms, classes, device, state, prev_state=prev_state)
            prev_state = state
            state = MyState()
            if output_video_path:
                # temp_buf.seek(0)
                # bytes_as_np_array = np.frombuffer(temp_buf.read(), dtype=np.uint8)
                # Read back the processed frame and write it to the video
                # processed_frame = cv2.imdecode(bytes_as_np_array, cv2.IMREAD_COLOR)
                out.write(frame)

                # Cleanup temporary files
                # os.remove(temp_output_path)

            # Cleanup the input temporary frame
            # os.remove(temp_image_path)

            frame_count += 1
            print("Frame: ", frame_count)
            # Display the processed frame
            if not output_video_path:
                cv2.imshow("Processed Frame", frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
    except KeyboardInterrupt:
        pass
    cap.release()
    if output_video_path:
        out.release()
    print("Total Frames:", frame_count)
    cv2.destroyAllWindows()

# %%
image_path = "./iran-dashcam.mp4"  # Replace with the path to your test image
save_path = "./hq-out-6.mp4"  # Replace or set to None to only display
import matplotlib
matplotlib.use('Agg')

process_input(
    input_path=image_path,
    yolo_model=yolo_model,
    ocr_model=ocr_model,
    ocr_transforms=ocr_transforms,
    classes=classes,
    device=device,
    output_path=save_path
)
# Out:
# 0: 384x640 (no detections), 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 0
# Frame:  1
#
# 0: 384x640 1   , 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  2
#
# 0: 384x640 1   , 60.3ms
# Speed: 5.0ms preprocess, 60.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  3
#
# 0: 384x640 1   , 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  4
#
# 0: 384x640 1   , 61.2ms
# Speed: 2.0ms preprocess, 61.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  5
#
# 0: 384x640 1   , 55.2ms
# Speed: 2.0ms preprocess, 55.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  6
#
# 0: 384x640 1   , 64.3ms
# Speed: 1.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  7
#
# 0: 384x640 1   , 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  8
#
# 0: 384x640 1   , 53.9ms
# Speed: 2.0ms preprocess, 53.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  9
#
# 0: 384x640 1   , 52.6ms
# Speed: 2.0ms preprocess, 52.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  10
#
# 0: 384x640 1   , 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  11
#
# 0: 384x640 1   , 52.4ms
# Speed: 3.0ms preprocess, 52.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  12
#
# 0: 384x640 1   , 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  13
#
# 0: 384x640 1   , 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  14
#
# 0: 384x640 1   , 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  15
#
# 0: 384x640 1   , 54.2ms
# Speed: 3.0ms preprocess, 54.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  16
#
# 0: 384x640 1   , 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  17
#
# 0: 384x640 1   , 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  18
#
# 0: 384x640 1   , 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  19
#
# 0: 384x640 1   , 61.5ms
# Speed: 1.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  20
#
# 0: 384x640 1   , 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  21
#
# 0: 384x640 1   , 53.6ms
# Speed: 2.0ms preprocess, 53.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  22
#
# 0: 384x640 1   , 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  23
#
# 0: 384x640 1   , 53.4ms
# Speed: 1.0ms preprocess, 53.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  24
#
# 0: 384x640 1   , 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  25
#
# 0: 384x640 1   , 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  26
#
# 0: 384x640 1   , 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  27
#
# 0: 384x640 1   , 64.5ms
# Speed: 1.0ms preprocess, 64.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  28
#
# 0: 384x640 1   , 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  29
#
# 0: 384x640 1   , 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  30
#
# 0: 384x640 1   , 48.5ms
# Speed: 2.0ms preprocess, 48.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  31
#
# 0: 384x640 1   , 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  32
#
# 0: 384x640 1   , 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  33
#
# 0: 384x640 1   , 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  34
#
# 0: 384x640 1   , 57.1ms
# Speed: 1.0ms preprocess, 57.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  35
#
# 0: 384x640 1   , 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  36
#
# 0: 384x640 1   , 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  37
#
# 0: 384x640 1   , 52.1ms
# Speed: 2.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  38
#
# 0: 384x640 1   , 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  39
#
# 0: 384x640 1   , 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  40
#
# 0: 384x640 1   , 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  41
#
# 0: 384x640 1   , 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  42
#
# 0: 384x640 1   , 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  43
#
# 0: 384x640 1   , 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  44
#
# 0: 384x640 1   , 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  45
#
# 0: 384x640 1   , 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  46
#
# 0: 384x640 1   , 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  47
#
# 0: 384x640 1   , 52.8ms
# Speed: 2.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  48
#
# 0: 384x640 1   , 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  49
#
# 0: 384x640 1   , 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  50
#
# 0: 384x640 1   , 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  51
#
# 0: 384x640 1   , 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  52
#
# 0: 384x640 1   , 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  53
#
# 0: 384x640 1   , 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  54
#
# 0: 384x640 1   , 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  55
#
# 0: 384x640 1   , 53.7ms
# Speed: 2.0ms preprocess, 53.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  56
#
# 0: 384x640 1   , 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  57
#
# 0: 384x640 2   s, 54.4ms
# Speed: 2.0ms preprocess, 54.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  58
#
# 0: 384x640 1   , 55.1ms
# Speed: 3.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  59
#
# 0: 384x640 1   , 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  60
#
# 0: 384x640 1   , 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  61
#
# 0: 384x640 1   , 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  62
#
# 0: 384x640 1   , 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  63
#
# 0: 384x640 1   , 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  64
#
# 0: 384x640 1   , 59.7ms
# Speed: 2.1ms preprocess, 59.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  65
#
# 0: 384x640 1   , 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  66
#
# 0: 384x640 1   , 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  67
#
# 0: 384x640 1   , 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  68
#
# 0: 384x640 1   , 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  69
#
# 0: 384x640 1   , 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  70
#
# 0: 384x640 1   , 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  71
#
# 0: 384x640 1   , 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  72
#
# 0: 384x640 1   , 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  73
#
# 0: 384x640 1   , 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  74
#
# 0: 384x640 1   , 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  75
#
# 0: 384x640 1   , 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  76
#
# 0: 384x640 1   , 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  77
#
# 0: 384x640 1   , 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  78
#
# 0: 384x640 1   , 54.6ms
# Speed: 3.0ms preprocess, 54.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  79
#
# 0: 384x640 1   , 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  80
#
# 0: 384x640 1   , 50.4ms
# Speed: 2.0ms preprocess, 50.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  81
#
# 0: 384x640 1   , 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  82
#
# 0: 384x640 1   , 50.3ms
# Speed: 2.0ms preprocess, 50.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  83
#
# 0: 384x640 1   , 60.3ms
# Speed: 3.0ms preprocess, 60.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  84
#
# 0: 384x640 1   , 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  85
#
# 0: 384x640 1   , 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  86
#
# 0: 384x640 1   , 58.4ms
# Speed: 2.2ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  87
#
# 0: 384x640 1   , 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  88
#
# 0: 384x640 1   , 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  89
#
# 0: 384x640 1   , 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  90
#
# 0: 384x640 1   , 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  91
#
# 0: 384x640 1   , 55.2ms
# Speed: 2.0ms preprocess, 55.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  92
#
# 0: 384x640 1   , 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  93
#
# 0: 384x640 1   , 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  94
#
# 0: 384x640 1   , 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  95
#
# 0: 384x640 1   , 65.6ms
# Speed: 2.4ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  96
#
# 0: 384x640 1   , 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  97
#
# 0: 384x640 2   s, 55.7ms
# Speed: 3.0ms preprocess, 55.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  98
#
# 0: 384x640 1   , 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  99
#
# 0: 384x640 1   , 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  100
#
# 0: 384x640 1   , 53.9ms
# Speed: 3.0ms preprocess, 53.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  101
#
# 0: 384x640 1   , 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  102
#
# 0: 384x640 1   , 56.1ms
# Speed: 2.1ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  103
#
# 0: 384x640 1   , 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  104
#
# 0: 384x640 1   , 55.9ms
# Speed: 2.4ms preprocess, 55.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  105
#
# 0: 384x640 1   , 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  106
#
# 0: 384x640 1   , 56.2ms
# Speed: 1.8ms preprocess, 56.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  107
#
# 0: 384x640 1   , 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  108
#
# 0: 384x640 1   , 62.0ms
# Speed: 2.6ms preprocess, 62.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  109
#
# 0: 384x640 2   s, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  110
#
# 0: 384x640 1   , 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  111
#
# 0: 384x640 1   , 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  112
#
# 0: 384x640 1   , 55.7ms
# Speed: 3.2ms preprocess, 55.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  113
#
# 0: 384x640 1   , 54.3ms
# Speed: 1.5ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  114
#
# 0: 384x640 2   s, 57.9ms
# Speed: 1.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  115
#
# 0: 384x640 2   s, 57.5ms
# Speed: 2.4ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  116
#
# 0: 384x640 1   , 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  117
#
# 0: 384x640 1   , 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  118
#
# 0: 384x640 1   , 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  119
#
# 0: 384x640 1   , 58.1ms
# Speed: 2.1ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  120
#
# 0: 384x640 1   , 54.9ms
# Speed: 2.0ms preprocess, 54.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  121
#
# 0: 384x640 1   , 49.6ms
# Speed: 2.0ms preprocess, 49.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  122
#
# 0: 384x640 1   , 62.7ms
# Speed: 2.5ms preprocess, 62.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  123
#
# 0: 384x640 1   , 56.4ms
# Speed: 2.5ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  124
#
# 0: 384x640 2   s, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  125
#
# 0: 384x640 1   , 57.3ms
# Speed: 3.0ms preprocess, 57.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  126
#
# 0: 384x640 1   , 54.3ms
# Speed: 2.0ms preprocess, 54.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  127
#
# 0: 384x640 2   s, 54.5ms
# Speed: 2.5ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  128
#
# 0: 384x640 1   , 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  129
#
# 0: 384x640 1   , 56.6ms
# Speed: 3.0ms preprocess, 56.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  130
#
# 0: 384x640 1   , 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  131
#
# 0: 384x640 1   , 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  132
#
# 0: 384x640 1   , 63.7ms
# Speed: 2.0ms preprocess, 63.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  133
#
# 0: 384x640 1   , 68.4ms
# Speed: 3.0ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  134
#
# 0: 384x640 1   , 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  135
#
# 0: 384x640 1   , 76.2ms
# Speed: 3.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  136
#
# 0: 384x640 1   , 60.3ms
# Speed: 3.1ms preprocess, 60.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  137
#
# 0: 384x640 1   , 74.8ms
# Speed: 3.0ms preprocess, 74.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  138
#
# 0: 384x640 1   , 73.1ms
# Speed: 3.0ms preprocess, 73.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  139
#
# 0: 384x640 1   , 65.4ms
# Speed: 2.0ms preprocess, 65.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  140
#
# 0: 384x640 1   , 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  141
#
# 0: 384x640 1   , 75.0ms
# Speed: 2.2ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  142
#
# 0: 384x640 2   s, 60.9ms
# Speed: 3.0ms preprocess, 60.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  143
#
# 0: 384x640 1   , 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  144
#
# 0: 384x640 1   , 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  145
#
# 0: 384x640 2   s, 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  146
#
# 0: 384x640 1   , 61.6ms
# Speed: 3.0ms preprocess, 61.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  147
#
# 0: 384x640 1   , 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  148
#
# 0: 384x640 1   , 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  149
#
# 0: 384x640 1   , 61.8ms
# Speed: 4.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  150
#
# 0: 384x640 1   , 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  151
#
# 0: 384x640 1   , 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  152
#
# 0: 384x640 1   , 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  153
#
# 0: 384x640 1   , 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  154
#
# 0: 384x640 1   , 66.3ms
# Speed: 1.0ms preprocess, 66.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  155
#
# 0: 384x640 1   , 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  156
#
# 0: 384x640 1   , 70.1ms
# Speed: 3.1ms preprocess, 70.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  157
#
# 0: 384x640 1   , 65.5ms
# Speed: 2.4ms preprocess, 65.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  158
#
# 0: 384x640 1   , 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  159
#
# 0: 384x640 1   , 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  160
#
# 0: 384x640 1   , 71.9ms
# Speed: 4.0ms preprocess, 71.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  161
#
# 0: 384x640 1   , 72.5ms
# Speed: 4.0ms preprocess, 72.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  162
#
# 0: 384x640 1   , 65.1ms
# Speed: 4.0ms preprocess, 65.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  163
#
# 0: 384x640 1   , 70.2ms
# Speed: 3.0ms preprocess, 70.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  164
#
# 0: 384x640 1   , 64.9ms
# Speed: 3.0ms preprocess, 64.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  165
#
# 0: 384x640 1   , 76.3ms
# Speed: 3.0ms preprocess, 76.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  166
#
# 0: 384x640 1   , 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  167
#
# 0: 384x640 1   , 71.7ms
# Speed: 2.0ms preprocess, 71.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  168
#
# 0: 384x640 1   , 64.1ms
# Speed: 4.0ms preprocess, 64.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  169
#
# 0: 384x640 1   , 130.1ms
# Speed: 3.0ms preprocess, 130.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  170
#
# 0: 384x640 1   , 78.0ms
# Speed: 3.5ms preprocess, 78.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  171
#
# 0: 384x640 1   , 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  172
#
# 0: 384x640 1   , 67.0ms
# Speed: 5.0ms preprocess, 67.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  173
#
# 0: 384x640 2   s, 69.2ms
# Speed: 3.0ms preprocess, 69.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  174
#
# 0: 384x640 2   s, 72.2ms
# Speed: 3.0ms preprocess, 72.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  175
#
# 0: 384x640 2   s, 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  176
#
# 0: 384x640 2   s, 68.2ms
# Speed: 3.0ms preprocess, 68.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  177
#
# 0: 384x640 2   s, 68.1ms
# Speed: 3.0ms preprocess, 68.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  178
#
# 0: 384x640 2   s, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  179
#
# 0: 384x640 2   s, 70.3ms
# Speed: 2.0ms preprocess, 70.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  180
#
# 0: 384x640 2   s, 72.1ms
# Speed: 2.0ms preprocess, 72.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  181
#
# 0: 384x640 2   s, 67.7ms
# Speed: 2.1ms preprocess, 67.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  182
#
# 0: 384x640 2   s, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  183
#
# 0: 384x640 2   s, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  184
#
# 0: 384x640 2   s, 61.1ms
# Speed: 3.0ms preprocess, 61.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  185
#
# 0: 384x640 2   s, 63.9ms
# Speed: 2.5ms preprocess, 63.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  186
#
# 0: 384x640 2   s, 63.8ms
# Speed: 3.0ms preprocess, 63.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  187
#
# 0: 384x640 2   s, 71.6ms
# Speed: 3.0ms preprocess, 71.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  188
#
# 0: 384x640 2   s, 64.2ms
# Speed: 2.1ms preprocess, 64.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  189
#
# 0: 384x640 2   s, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  190
#
# 0: 384x640 2   s, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  191
#
# 0: 384x640 2   s, 67.6ms
# Speed: 2.0ms preprocess, 67.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  192
#
# 0: 384x640 2   s, 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  193
#
# 0: 384x640 2   s, 75.4ms
# Speed: 4.0ms preprocess, 75.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  194
#
# 0: 384x640 2   s, 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  195
#
# 0: 384x640 2   s, 69.7ms
# Speed: 3.1ms preprocess, 69.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  196
#
# 0: 384x640 2   s, 69.3ms
# Speed: 3.0ms preprocess, 69.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  197
#
# 0: 384x640 2   s, 73.3ms
# Speed: 3.0ms preprocess, 73.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  198
#
# 0: 384x640 2   s, 66.9ms
# Speed: 2.2ms preprocess, 66.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  199
#
# 0: 384x640 2   s, 70.7ms
# Speed: 3.0ms preprocess, 70.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  200
#
# 0: 384x640 2   s, 72.1ms
# Speed: 2.4ms preprocess, 72.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  201
#
# 0: 384x640 2   s, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  202
#
# 0: 384x640 2   s, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  203
#
# 0: 384x640 2   s, 60.9ms
# Speed: 2.2ms preprocess, 60.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  204
#
# 0: 384x640 2   s, 61.8ms
# Speed: 3.0ms preprocess, 61.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  205
#
# 0: 384x640 2   s, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  206
#
# 0: 384x640 2   s, 70.9ms
# Speed: 3.4ms preprocess, 70.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  207
#
# 0: 384x640 2   s, 60.7ms
# Speed: 2.1ms preprocess, 60.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  208
#
# 0: 384x640 2   s, 70.3ms
# Speed: 2.0ms preprocess, 70.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  209
#
# 0: 384x640 2   s, 74.5ms
# Speed: 3.0ms preprocess, 74.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  210
#
# 0: 384x640 2   s, 62.4ms
# Speed: 2.0ms preprocess, 62.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  211
#
# 0: 384x640 2   s, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  212
#
# 0: 384x640 2   s, 70.5ms
# Speed: 2.0ms preprocess, 70.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  213
#
# 0: 384x640 2   s, 68.8ms
# Speed: 3.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  214
#
# 0: 384x640 2   s, 59.7ms
# Speed: 2.0ms preprocess, 59.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  215
#
# 0: 384x640 2   s, 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  216
#
# 0: 384x640 2   s, 63.7ms
# Speed: 2.0ms preprocess, 63.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  217
#
# 0: 384x640 2   s, 71.4ms
# Speed: 4.0ms preprocess, 71.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  218
#
# 0: 384x640 2   s, 67.7ms
# Speed: 4.5ms preprocess, 67.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  219
#
# 0: 384x640 2   s, 65.2ms
# Speed: 3.0ms preprocess, 65.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  220
#
# 0: 384x640 2   s, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  221
#
# 0: 384x640 2   s, 73.0ms
# Speed: 3.0ms preprocess, 73.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  222
#
# 0: 384x640 2   s, 67.9ms
# Speed: 3.0ms preprocess, 67.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  223
#
# 0: 384x640 2   s, 68.9ms
# Speed: 2.0ms preprocess, 68.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  224
#
# 0: 384x640 2   s, 69.0ms
# Speed: 3.0ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  225
#
# 0: 384x640 2   s, 61.6ms
# Speed: 3.0ms preprocess, 61.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  226
#
# 0: 384x640 2   s, 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  227
#
# 0: 384x640 2   s, 65.6ms
# Speed: 2.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  228
#
# 0: 384x640 2   s, 69.3ms
# Speed: 2.0ms preprocess, 69.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  229
#
# 0: 384x640 2   s, 72.5ms
# Speed: 2.0ms preprocess, 72.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  230
#
# 0: 384x640 2   s, 70.1ms
# Speed: 4.0ms preprocess, 70.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  231
#
# 0: 384x640 2   s, 77.4ms
# Speed: 2.0ms preprocess, 77.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  232
#
# 0: 384x640 2   s, 68.4ms
# Speed: 3.0ms preprocess, 68.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  233
#
# 0: 384x640 2   s, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  234
#
# 0: 384x640 2   s, 71.3ms
# Speed: 3.0ms preprocess, 71.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  235
#
# 0: 384x640 2   s, 70.1ms
# Speed: 2.0ms preprocess, 70.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  236
#
# 0: 384x640 2   s, 71.1ms
# Speed: 4.0ms preprocess, 71.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  237
#
# 0: 384x640 2   s, 71.7ms
# Speed: 3.0ms preprocess, 71.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  238
#
# 0: 384x640 2   s, 73.9ms
# Speed: 4.0ms preprocess, 73.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  239
#
# 0: 384x640 2   s, 75.2ms
# Speed: 4.0ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  240
#
# 0: 384x640 2   s, 88.1ms
# Speed: 4.0ms preprocess, 88.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  241
#
# 0: 384x640 2   s, 70.4ms
# Speed: 4.0ms preprocess, 70.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  242
#
# 0: 384x640 2   s, 64.9ms
# Speed: 3.0ms preprocess, 64.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  243
#
# 0: 384x640 2   s, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  244
#
# 0: 384x640 2   s, 67.9ms
# Speed: 3.0ms preprocess, 67.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  245
#
# 0: 384x640 2   s, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  246
#
# 0: 384x640 2   s, 66.0ms
# Speed: 4.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  247
#
# 0: 384x640 2   s, 60.6ms
# Speed: 4.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  248
#
# 0: 384x640 2   s, 65.6ms
# Speed: 4.0ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  249
#
# 0: 384x640 2   s, 66.4ms
# Speed: 3.0ms preprocess, 66.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  250
#
# 0: 384x640 2   s, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  251
#
# 0: 384x640 2   s, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  252
#
# 0: 384x640 2   s, 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  253
#
# 0: 384x640 2   s, 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  254
#
# 0: 384x640 2   s, 65.4ms
# Speed: 3.0ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  255
#
# 0: 384x640 2   s, 65.4ms
# Speed: 3.0ms preprocess, 65.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  256
#
# 0: 384x640 2   s, 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  257
#
# 0: 384x640 2   s, 62.9ms
# Speed: 3.4ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  258
#
# 0: 384x640 2   s, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  259
#
# 0: 384x640 2   s, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  260
#
# 0: 384x640 2   s, 60.3ms
# Speed: 3.0ms preprocess, 60.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  261
#
# 0: 384x640 2   s, 58.4ms
# Speed: 2.1ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  262
#
# 0: 384x640 2   s, 66.2ms
# Speed: 3.3ms preprocess, 66.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  263
#
# 0: 384x640 2   s, 77.5ms
# Speed: 2.1ms preprocess, 77.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  264
#
# 0: 384x640 2   s, 71.0ms
# Speed: 3.0ms preprocess, 71.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  265
#
# 0: 384x640 2   s, 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  266
#
# 0: 384x640 2   s, 63.6ms
# Speed: 3.0ms preprocess, 63.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  267
#
# 0: 384x640 2   s, 59.2ms
# Speed: 2.0ms preprocess, 59.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  268
#
# 0: 384x640 2   s, 68.7ms
# Speed: 2.0ms preprocess, 68.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  269
#
# 0: 384x640 2   s, 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  270
#
# 0: 384x640 2   s, 71.7ms
# Speed: 3.0ms preprocess, 71.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  271
#
# 0: 384x640 2   s, 60.9ms
# Speed: 1.0ms preprocess, 60.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  272
#
# 0: 384x640 2   s, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  273
#
# 0: 384x640 2   s, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  274
#
# 0: 384x640 2   s, 66.4ms
# Speed: 3.0ms preprocess, 66.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  275
#
# 0: 384x640 2   s, 63.1ms
# Speed: 1.0ms preprocess, 63.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  276
#
# 0: 384x640 2   s, 89.6ms
# Speed: 2.0ms preprocess, 89.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  277
#
# 0: 384x640 2   s, 65.4ms
# Speed: 2.4ms preprocess, 65.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  278
#
# 0: 384x640 2   s, 59.2ms
# Speed: 3.0ms preprocess, 59.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  279
#
# 0: 384x640 2   s, 64.3ms
# Speed: 3.0ms preprocess, 64.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  280
#
# 0: 384x640 2   s, 63.7ms
# Speed: 3.0ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  281
#
# 0: 384x640 2   s, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  282
#
# 0: 384x640 2   s, 61.3ms
# Speed: 3.0ms preprocess, 61.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  283
#
# 0: 384x640 2   s, 66.9ms
# Speed: 3.0ms preprocess, 66.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  284
#
# 0: 384x640 2   s, 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  285
#
# 0: 384x640 2   s, 62.8ms
# Speed: 3.0ms preprocess, 62.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  286
#
# 0: 384x640 2   s, 62.3ms
# Speed: 3.0ms preprocess, 62.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  287
#
# 0: 384x640 2   s, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  288
#
# 0: 384x640 2   s, 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  289
#
# 0: 384x640 2   s, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  290
#
# 0: 384x640 2   s, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  291
#
# 0: 384x640 2   s, 67.5ms
# Speed: 3.2ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  292
#
# 0: 384x640 2   s, 57.9ms
# Speed: 3.0ms preprocess, 57.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  293
#
# 0: 384x640 2   s, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  294
#
# 0: 384x640 2   s, 59.9ms
# Speed: 2.0ms preprocess, 59.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  295
#
# 0: 384x640 2   s, 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  296
#
# 0: 384x640 2   s, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  297
#
# 0: 384x640 2   s, 66.1ms
# Speed: 3.0ms preprocess, 66.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  298
#
# 0: 384x640 2   s, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  299
#
# 0: 384x640 2   s, 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  300
#
# 0: 384x640 2   s, 63.4ms
# Speed: 3.0ms preprocess, 63.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  301
#
# 0: 384x640 2   s, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  302
#
# 0: 384x640 2   s, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  303
#
# 0: 384x640 2   s, 65.2ms
# Speed: 3.0ms preprocess, 65.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  304
#
# 0: 384x640 2   s, 60.8ms
# Speed: 3.3ms preprocess, 60.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  305
#
# 0: 384x640 2   s, 61.8ms
# Speed: 3.0ms preprocess, 61.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  306
#
# 0: 384x640 2   s, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  307
#
# 0: 384x640 2   s, 61.8ms
# Speed: 3.0ms preprocess, 61.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  308
#
# 0: 384x640 2   s, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  309
#
# 0: 384x640 2   s, 73.2ms
# Speed: 2.0ms preprocess, 73.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  310
#
# 0: 384x640 2   s, 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  311
#
# 0: 384x640 2   s, 68.1ms
# Speed: 2.0ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  312
#
# 0: 384x640 2   s, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  313
#
# 0: 384x640 2   s, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  314
#
# 0: 384x640 2   s, 57.4ms
# Speed: 1.4ms preprocess, 57.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  315
#
# 0: 384x640 2   s, 78.0ms
# Speed: 3.4ms preprocess, 78.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  316
#
# 0: 384x640 2   s, 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  317
#
# 0: 384x640 2   s, 73.0ms
# Speed: 3.0ms preprocess, 73.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  318
#
# 0: 384x640 2   s, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  319
#
# 0: 384x640 2   s, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  320
#
# 0: 384x640 2   s, 65.3ms
# Speed: 1.0ms preprocess, 65.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  321
#
# 0: 384x640 2   s, 65.3ms
# Speed: 1.0ms preprocess, 65.3ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  322
#
# 0: 384x640 2   s, 69.2ms
# Speed: 4.0ms preprocess, 69.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  323
#
# 0: 384x640 2   s, 60.3ms
# Speed: 2.1ms preprocess, 60.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  324
#
# 0: 384x640 2   s, 64.6ms
# Speed: 1.0ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  325
#
# 0: 384x640 2   s, 57.2ms
# Speed: 2.9ms preprocess, 57.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  326
#
# 0: 384x640 2   s, 72.3ms
# Speed: 3.0ms preprocess, 72.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  327
#
# 0: 384x640 2   s, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  328
#
# 0: 384x640 2   s, 64.4ms
# Speed: 1.0ms preprocess, 64.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  329
#
# 0: 384x640 2   s, 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  330
#
# 0: 384x640 2   s, 68.4ms
# Speed: 1.5ms preprocess, 68.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  331
#
# 0: 384x640 2   s, 68.2ms
# Speed: 3.0ms preprocess, 68.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  332
#
# 0: 384x640 2   s, 69.3ms
# Speed: 3.0ms preprocess, 69.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  333
#
# 0: 384x640 2   s, 71.1ms
# Speed: 3.2ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  334
#
# 0: 384x640 2   s, 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  335
#
# ...
# boxes: 2
# Frame:  1042
#
# 0: 384x640 2   s, 68.8ms
# Speed: 3.0ms preprocess, 68.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1043
#
# 0: 384x640 2   s, 65.1ms
# Speed: 3.0ms preprocess, 65.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1044
#
# 0: 384x640 2   s, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1045
#
# 0: 384x640 3   s, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 3
# Frame:  1046
#
# 0: 384x640 2   s, 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1047
#
# 0: 384x640 2   s, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1048
#
# 0: 384x640 3   s, 72.5ms
# Speed: 4.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 3
# Frame:  1049
#
# 0: 384x640 3   s, 68.0ms
# Speed: 2.7ms preprocess, 68.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 3
# Frame:  1050
#
# 0: 384x640 2   s, 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1051
#
# 0: 384x640 1   , 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1052
#
# 0: 384x640 1   , 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1053
#
# 0: 384x640 2   s, 64.7ms
# Speed: 3.0ms preprocess, 64.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1054
#
# 0: 384x640 1   , 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1055
#
# 0: 384x640 2   s, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1056
#
# 0: 384x640 2   s, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1057
#
# 0: 384x640 1   , 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1058
#
# 0: 384x640 2   s, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1059
#
# 0: 384x640 2   s, 67.8ms
# Speed: 3.0ms preprocess, 67.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1060
#
# 0: 384x640 1   , 56.8ms
# Speed: 3.0ms preprocess, 56.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1061
#
# 0: 384x640 2   s, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1062
#
# 0: 384x640 2   s, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1063
#
# 0: 384x640 2   s, 61.8ms
# Speed: 2.0ms preprocess, 61.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1064
#
# 0: 384x640 2   s, 64.3ms
# Speed: 2.0ms preprocess, 64.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1065
#
# 0: 384x640 2   s, 62.3ms
# Speed: 2.1ms preprocess, 62.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1066
#
# 0: 384x640 2   s, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1067
#
# 0: 384x640 2   s, 66.3ms
# Speed: 3.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1068
#
# 0: 384x640 2   s, 64.3ms
# Speed: 3.0ms preprocess, 64.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1069
#
# 0: 384x640 2   s, 57.2ms
# Speed: 1.1ms preprocess, 57.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1070
#
# 0: 384x640 3   s, 67.9ms
# Speed: 2.1ms preprocess, 67.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 3
# Frame:  1071
#
# 0: 384x640 2   s, 66.9ms
# Speed: 2.0ms preprocess, 66.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1072
#
# 0: 384x640 3   s, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 3
# Frame:  1073
#
# 0: 384x640 2   s, 62.3ms
# Speed: 3.4ms preprocess, 62.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1074
#
# 0: 384x640 2   s, 56.4ms
# Speed: 1.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1075
#
# 0: 384x640 2   s, 64.0ms
# Speed: 4.6ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1076
#
# 0: 384x640 2   s, 67.2ms
# Speed: 2.0ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1077
#
# 0: 384x640 1   , 60.4ms
# Speed: 3.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1078
#
# 0: 384x640 2   s, 57.6ms
# Speed: 2.3ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1079
#
# 0: 384x640 2   s, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1080
#
# 0: 384x640 2   s, 58.7ms
# Speed: 2.0ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1081
#
# 0: 384x640 2   s, 64.9ms
# Speed: 3.0ms preprocess, 64.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1082
#
# 0: 384x640 1   , 68.1ms
# Speed: 3.0ms preprocess, 68.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1083
#
# 0: 384x640 2   s, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1084
#
# 0: 384x640 2   s, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1085
#
# 0: 384x640 2   s, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1086
#
# 0: 384x640 2   s, 73.1ms
# Speed: 3.0ms preprocess, 73.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1087
#
# 0: 384x640 2   s, 58.3ms
# Speed: 3.0ms preprocess, 58.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1088
#
# 0: 384x640 3   s, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 3
# Frame:  1089
#
# 0: 384x640 2   s, 64.4ms
# Speed: 2.4ms preprocess, 64.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1090
#
# 0: 384x640 2   s, 65.6ms
# Speed: 2.0ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1091
#
# 0: 384x640 2   s, 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1092
#
# 0: 384x640 1   , 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1093
#
# 0: 384x640 1   , 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1094
#
# 0: 384x640 2   s, 65.7ms
# Speed: 2.0ms preprocess, 65.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1095
#
# 0: 384x640 1   , 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1096
#
# 0: 384x640 2   s, 68.3ms
# Speed: 3.0ms preprocess, 68.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1097
#
# 0: 384x640 2   s, 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1098
#
# 0: 384x640 2   s, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1099
#
# 0: 384x640 1   , 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1100
#
# 0: 384x640 2   s, 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1101
#
# 0: 384x640 2   s, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1102
#
# 0: 384x640 2   s, 86.4ms
# Speed: 3.0ms preprocess, 86.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1103
#
# 0: 384x640 1   , 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1104
#
# 0: 384x640 2   s, 61.3ms
# Speed: 3.0ms preprocess, 61.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1105
#
# 0: 384x640 1   , 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1106
#
# 0: 384x640 1   , 72.2ms
# Speed: 3.0ms preprocess, 72.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1107
#
# 0: 384x640 2   s, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1108
#
# 0: 384x640 1   , 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1109
#
# 0: 384x640 1   , 68.2ms
# Speed: 2.5ms preprocess, 68.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1110
#
# 0: 384x640 1   , 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1111
#
# 0: 384x640 1   , 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1112
#
# 0: 384x640 1   , 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1113
#
# 0: 384x640 1   , 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1114
#
# 0: 384x640 1   , 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1115
#
# 0: 384x640 1   , 64.9ms
# Speed: 4.0ms preprocess, 64.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1116
#
# 0: 384x640 1   , 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1117
#
# 0: 384x640 2   s, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1118
#
# 0: 384x640 2   s, 74.3ms
# Speed: 2.0ms preprocess, 74.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1119
#
# 0: 384x640 1   , 69.0ms
# Speed: 3.0ms preprocess, 69.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1120
#
# 0: 384x640 2   s, 62.3ms
# Speed: 1.3ms preprocess, 62.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1121
#
# 0: 384x640 2   s, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1122
#
# 0: 384x640 2   s, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1123
#
# 0: 384x640 2   s, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1124
#
# 0: 384x640 1   , 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1125
#
# 0: 384x640 2   s, 67.9ms
# Speed: 3.0ms preprocess, 67.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1126
#
# 0: 384x640 (no detections), 64.3ms
# Speed: 2.0ms preprocess, 64.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 0
# Frame:  1127
#
# 0: 384x640 1   , 69.8ms
# Speed: 3.0ms preprocess, 69.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1128
#
# 0: 384x640 1   , 63.1ms
# Speed: 1.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1129
#
# 0: 384x640 1   , 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1130
#
# 0: 384x640 1   , 71.0ms
# Speed: 3.0ms preprocess, 71.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1131
#
# 0: 384x640 1   , 74.8ms
# Speed: 2.0ms preprocess, 74.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1132
#
# 0: 384x640 2   s, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1133
#
# 0: 384x640 1   , 72.1ms
# Speed: 2.0ms preprocess, 72.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1134
#
# 0: 384x640 1   , 61.7ms
# Speed: 2.0ms preprocess, 61.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1135
#
# 0: 384x640 (no detections), 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 0
# Frame:  1136
#
# 0: 384x640 2   s, 71.2ms
# Speed: 3.0ms preprocess, 71.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1137
#
# 0: 384x640 1   , 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1138
#
# 0: 384x640 1   , 64.2ms
# Speed: 3.0ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1139
#
# 0: 384x640 2   s, 74.2ms
# Speed: 4.0ms preprocess, 74.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1140
#
# 0: 384x640 2   s, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1141
#
# 0: 384x640 2   s, 63.6ms
# Speed: 3.0ms preprocess, 63.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1142
#
# 0: 384x640 1   , 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1143
#
# 0: 384x640 2   s, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1144
#
# 0: 384x640 2   s, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1145
#
# 0: 384x640 1   , 68.9ms
# Speed: 3.0ms preprocess, 68.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1146
#
# 0: 384x640 2   s, 68.4ms
# Speed: 2.1ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1147
#
# 0: 384x640 1   , 64.2ms
# Speed: 3.0ms preprocess, 64.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1148
#
# 0: 384x640 1   , 77.8ms
# Speed: 2.5ms preprocess, 77.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1149
#
# 0: 384x640 2   s, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 2
# Frame:  1150
#
# 0: 384x640 1   , 63.0ms
# Speed: 2.2ms preprocess, 63.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1151
#
# 0: 384x640 1   , 65.3ms
# Speed: 3.0ms preprocess, 65.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# boxes: 1
# Frame:  1152
#
# Total Frames: 1152

# %%
cv2.destroyAllWindows()
