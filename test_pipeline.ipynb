# %%
import torch
from torchvision.transforms import transforms
from PIL import Image
import cv2
import numpy as np
import json
from ultralytics import YOLO

# %%
# Load OCR Model
class CNN(torch.nn.Module):
    def __init__(self, in_size=(200, 50, 1), conv_out_1=32, conv_kern_1=3, conv_out_2=64,
                 conv_kern_2=3, fc1_out=64, lstm1_out=128, lstm2_out=64, fc2_out=38):
        super(CNN, self).__init__()
        w, h, c = in_size
        self.conv1 = torch.nn.Conv2d(c, conv_out_1, kernel_size=conv_kern_1, padding="same")
        self.conv2 = torch.nn.Conv2d(conv_out_1, conv_out_2, kernel_size=conv_kern_2, padding="same")
        self.fc1 = torch.nn.Linear(conv_out_2, fc1_out)
        self.lstm1 = torch.nn.LSTM(fc1_out * (h // 4), lstm1_out, bidirectional=True, batch_first=True)
        self.lstm2 = torch.nn.LSTM(lstm1_out * 2, lstm2_out, bidirectional=True, batch_first=True)
        self.fc2 = torch.nn.Linear(lstm2_out * 2, fc2_out)

    def forward(self, x):
        batch_size, c, h, w = x.shape
        x = torch.relu(self.conv1(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = torch.relu(self.conv2(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = x.permute(0, 3, 2, 1)
        x = torch.relu(self.fc1(x))
        x = torch.dropout(x, p=0.2, train=False)
        x = x.reshape(batch_size, w // 4, -1)
        x, _ = self.lstm1(x)
        x = torch.dropout(x, p=0.25, train=False)
        x, _ = self.lstm2(x)
        x = torch.dropout(x, p=0.25, train=False)
        x = torch.log_softmax(self.fc2(x), dim=-1)
        return x.permute(1, 0, 2)

# %%
import pandas as pd
import os
# Load character classes
with open("/home/infres/lotfi-23/notebooks/classes.json", "r") as f:
    classes = json.load(f)

# Load OCR Model and Classes
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
ocr_model = CNN(fc2_out=(len(classes) + 1))  # Adjust `fc2_out` based on your trained model
# ocr_model.load_state_dict(torch.load('/home/infres/lotfi-23/training/weights_last.pth', map_location=device))
ocr_model = torch.load("/home/infres/lotfi-23/notebooks/saved_models/model_epoch_200.pth")
ocr_model = ocr_model.to(device)
ocr_model.eval()



# Define transforms for the OCR model
ocr_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.ConvertImageDtype(torch.float32)
])

# Decode predictions
def decode_predictions(predictions, classes):
    pred_str = ''.join([classes[c - 1] if c != 0 else '_' for c in predictions])
    pred_str = ''.join(ch for i, ch in enumerate(pred_str) if ch != '_' and (i == 0 or ch != pred_str[i - 1]))
    return pred_str

# Load YOLOv8 Model
yolo_model = YOLO("/home/infres/lotfi-23/notebooks/yolo-best.pt")  # Replace with your YOLOv8 model path

# Full Inference Pipeline
def infer_license_plate(image_path, yolo_model, ocr_model, ocr_transforms, classes, device):
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Could not read image at {image_path}")

    results = yolo_model(image)
    if len(results[0].boxes) == 0:
        raise ValueError("No license plate detected.")

    bbox = results[0].boxes[0].xyxy[0].cpu().numpy()
    x_min, y_min, x_max, y_max = map(int, bbox)
    plate_image = image[y_min:y_max, x_min:x_max]

    plate_image_pil = Image.fromarray(cv2.cvtColor(plate_image, cv2.COLOR_BGR2RGB)).convert('L')
    plate_image_resized = plate_image_pil.resize((200, 50))
    plate_tensor = ocr_transforms(plate_image_resized).unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = ocr_model(plate_tensor)
        predictions = outputs.argmax(dim=-1).cpu().numpy()[:, 0]

    return decode_predictions(predictions, classes)

# Filter Ground Truth
def filter_ground_truth(csv_path):
    """
    Filter the ground truth based on:
    - No spaces in the plate string.
    - Plate string length equals 8.
    - Plate string starts with two digits followed by a non-digit.
    """
    df = pd.read_csv(csv_path)
    df = df[~df['plateString'].str.contains(' ', na=True)]
    df = df[df['plateString'].str.len().eq(8)]
    df = df[df['plateString'].str.match(r'^\d{2}[^0-9]')]

    df['nameOfTheFile'] = df['nameOfTheFile'] + ".jpg"
    return df

# %%
import pandas as pd
import os
import time

# ground_truth_csv = "/home/infres/lotfi-23/test/string_plate_test.csv"
# filtered_ground_truth = filter_ground_truth(ground_truth_csv)
# filtered_images = dict(zip(filtered_ground_truth['nameOfTheFile'], filtered_ground_truth['plateString']))

# Evaluate on filtered data with timing
def infer_and_evaluate_filtered_with_timing(yolo_model, ocr_model, ocr_transforms, classes, device, image_dir, filtered_images):
    correct = 0
    total = len(filtered_images)
    results = []
    total_time = 0  # To accumulate inference times

    for img_name, gt_text in filtered_images.items():
        img_path = os.path.join(image_dir, img_name)
        if not os.path.isfile(img_path):
            print(f"File not found: {img_path}")
            continue

        try:
            # Start timing
            start_time = time.time()
            
            # Run end-to-end inference
            plate_text = infer_license_plate(img_path, yolo_model, ocr_model, ocr_transforms, classes, device)
            
            # End timing
            end_time = time.time()
            inference_time = end_time - start_time
            total_time += inference_time

            match = plate_text == gt_text  # Case-insensitive comparison
            correct += int(match)
            print(f"Image: {img_name}, GT: {gt_text}, Pred: {plate_text}, Match: {match}, Time: {inference_time:.4f}s")

            results.append({
                'image_name': img_name,
                'ground_truth': gt_text,
                'prediction': plate_text,
                'match': match,
                'inference_time': inference_time
            })

        except ValueError as e:
            print(f"Skipping {img_name}: {e}")
            results.append({
                'image_name': img_name,
                'ground_truth': gt_text,
                'prediction': None,
                'match': False,
                'inference_time': None
            })

    accuracy = correct / total * 100 if total > 0 else 0
    average_time = total_time / total if total > 0 else 0
    print(f"Accuracy on filtered data: {accuracy:.2f}%")
    print(f"Average inference time per image: {average_time:.4f}s")
    return results, accuracy, average_time

# Main execution
ground_truth_csv = "/home/infres/lotfi-23/test/string_plate_test.csv"
test_images_dir = "/home/infres/lotfi-23/test/Images"

filtered_ground_truth = filter_ground_truth(ground_truth_csv)
print(f"filtered_ground_truth: {filtered_ground_truth}")
filtered_images = dict(zip(filtered_ground_truth['nameOfTheFile'], filtered_ground_truth['plateString']))

results, accuracy, avg_inference_time = infer_and_evaluate_filtered_with_timing(
    yolo_model, ocr_model, ocr_transforms, classes, device, test_images_dir, filtered_images
)

results_df = pd.DataFrame(results)
results_df.to_csv("filtered_inference_results.csv", index=False)
print("Results saved to 'filtered_inference_results.csv'")
print(f"Average inference time per image: {avg_inference_time:.4f}s")
# Out:
ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_10290.jpg, GT: 83V92810, Pred: 83V92810, Match: True, Time: 0.0234s
#
# 0: 384x640 1 کل ناحیه پلاک, 8.1ms
# Speed: 0.9ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_15269.jpg, GT: 69S65916, Pred: 69S65916, Match: True, Time: 0.0210s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_11377.jpg, GT: 72D22111, Pred: 72D22111, Match: True, Time: 0.0234s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_06189.jpg, GT: 79M22788, Pred: 79M22788, Match: True, Time: 0.0258s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_08425.jpg, GT: 35N78568, Pred: 35N78568, Match: True, Time: 0.0279s
#
# 0: 544x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
# Image: day_05202.jpg, GT: 15H42366, Pred: 15H42366, Match: True, Time: 0.0176s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.7ms preprocess, 7.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
# Image: night (760).jpg, GT: 95D62710, Pred: 95D62710, Match: True, Time: 0.0218s
#
# 0: 640x320 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 320)
# Image: day_03449.jpg, GT: 34D89879, Pred: 34D89879, Match: True, Time: 0.0150s
#
# 0: 544x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
# Image: day_14110.jpg, GT: 37J59789, Pred: 37J59789, Match: True, Time: 0.0160s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.4ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_09604.jpg, GT: 82V24463, Pred: 86V24443, Match: False, Time: 0.0158s
#
# 0: 480x640 2 کل ناحیه پلاکs, 7.4ms
# Speed: 1.4ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_08044.jpg, GT: 18N99643, Pred: 18N99643, Match: True, Time: 0.0156s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_14571.jpg, GT: 38H78610, Pred: 38H78610, Match: True, Time: 0.0228s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.1ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: night (2967).jpg, GT: 36L45216, Pred: 65L48716, Match: False, Time: 0.0250s
#
# 0: 480x640 1 کل ناحیه پلاک, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_16920.jpg, GT: 21Ṣ16666, Pred: 21Ṣ16666, Match: True, Time: 0.0275s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_05574.jpg, GT: 95H32677, Pred: 95H32677, Match: True, Time: 0.0275s
#
# 0: 640x384 1 کل ناحیه پلاک, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_08886.jpg, GT: 77T16222, Pred: 77T16222, Match: True, Time: 0.0254s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_06124.jpg, GT: 29S48838, Pred: 29S48838, Match: True, Time: 0.0236s
#
# 0: 640x480 1 کل ناحیه پلاک, 8.1ms
# Speed: 1.3ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_04671.jpg, GT: 98Y16822, Pred: 98Y16822, Match: True, Time: 0.0249s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_05031.jpg, GT: 18T66122, Pred: 18T66122, Match: True, Time: 0.0220s
#
# 0: 448x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.2ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Image: day_09056.jpg, GT: 91J65620, Pred: 91J65620, Match: True, Time: 0.0148s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_06937.jpg, GT: 79D84744, Pred: 79D84744, Match: True, Time: 0.0290s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_05822.jpg, GT: 28S56822, Pred: 28S56822, Match: True, Time: 0.0263s
#
# 0: 640x544 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 544)
# Image: night (1531).jpg, GT: 28L36456, Pred: 28L36456, Match: True, Time: 0.0171s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: night (3878).jpg, GT: 88Ṭ56816, Pred: 88Ṭ56816, Match: True, Time: 0.0218s
#
# 0: 640x512 1 کل ناحیه پلاک, 7.4ms
# Speed: 1.6ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
# Image: night (1455).jpg, GT: 88O18678, Pred: 88O18678, Match: True, Time: 0.0199s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_16761.jpg, GT: 13Ṣ92464, Pred: 13Ṣ92464, Match: True, Time: 0.0251s
#
# 0: 576x640 1 کل ناحیه پلاک, 7.4ms
# Speed: 1.6ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
# Image: day_09341.jpg, GT: 98Q86593, Pred: 98Q86593, Match: True, Time: 0.0155s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.2ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_14034.jpg, GT: 91D33766, Pred: 91V33766, Match: False, Time: 0.0264s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.4ms
# Speed: 1.3ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_06594.jpg, GT: 19Ṣ58744, Pred: 19Ṣ58744, Match: True, Time: 0.0257s
#
# 0: 384x640 1 کل ناحیه پلاک, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_15674.jpg, GT: 66S52518, Pred: 66S52518, Match: True, Time: 0.0246s
#
# 0: 640x480 1 کل ناحیه پلاک, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_09720.jpg, GT: 74S65611, Pred: 74S65611, Match: True, Time: 0.0270s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: night (789).jpg, GT: 37M47488, Pred: 37M47488, Match: True, Time: 0.0174s
#
# 0: 640x480 1 کل ناحیه پلاک, 8.1ms
# Speed: 1.3ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_00019.jpg, GT: 95M88199, Pred: 95M88199, Match: True, Time: 0.0265s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.3ms
# Speed: 1.3ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_01659.jpg, GT: 21Ṣ54895, Pred: 21Ṣ54895, Match: True, Time: 0.0216s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_15215.jpg, GT: 87Q28516, Pred: 87Q28516, Match: True, Time: 0.0208s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: night (4016).jpg, GT: 55M52616, Pred: 55M52616, Match: True, Time: 0.0224s
#
# 0: 480x640 2 کل ناحیه پلاکs, 8.0ms
# Speed: 1.2ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_01360.jpg, GT: 26M92998, Pred: 26M92998, Match: True, Time: 0.0233s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: night (3113).jpg, GT: 86Ṣ21116, Pred: 86Ṣ21116, Match: True, Time: 0.0223s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: night (1026).jpg, GT: 25M52798, Pred: 25M52798, Match: True, Time: 0.0189s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_00287.jpg, GT: 27L98699, Pred: 27L98699, Match: True, Time: 0.0241s
#
# 0: 640x384 2 کل ناحیه پلاکs, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: night (3077).jpg, GT: 46L44716, Pred: 46L44716, Match: True, Time: 0.0224s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_10861.jpg, GT: 52Q54529, Pred: 52Q54529, Match: True, Time: 0.0236s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_11253.jpg, GT: 45Q46329, Pred: 45Q46329, Match: True, Time: 0.0202s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_11986.jpg, GT: 98H88422, Pred: 98H88422, Match: True, Time: 0.0250s
#
# 0: 512x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Image: day_05169.jpg, GT: 76L56638, Pred: 76L56638, Match: True, Time: 0.0171s
#
# 0: 608x640 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.5ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
# Image: day_03722.jpg, GT: 69B94566, Pred: 69B94566, Match: True, Time: 0.0148s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_02162.jpg, GT: 39B19336, Pred: 39B19336, Match: True, Time: 0.0227s
#
# 0: 640x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: day_03343.jpg, GT: 21M57138, Pred: 21M57138, Match: True, Time: 0.0171s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_15963.jpg, GT: 41B65699, Pred: 41B65699, Match: True, Time: 0.0222s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_02048.jpg, GT: 56M57512, Pred: 56M57512, Match: True, Time: 0.0231s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.5ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_09024.jpg, GT: 46S94993, Pred: 46S94993, Match: True, Time: 0.0184s
#
# 0: 480x640 2 کل ناحیه پلاکs, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_16876.jpg, GT: 78Ṭ98188, Pred: 78Ṭ98188, Match: True, Time: 0.0254s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_04603.jpg, GT: 33Ṭ77182, Pred: 33Ṭ77182, Match: True, Time: 0.0215s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_06290.jpg, GT: 26S76538, Pred: 26S76538, Match: True, Time: 0.0231s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.1ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_06537.jpg, GT: 86D42568, Pred: 86D42568, Match: True, Time: 0.0234s
#
# 0: 640x480 1 کل ناحیه پلاک, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_10189.jpg, GT: 51D63972, Pred: 51D63972, Match: True, Time: 0.0267s
#
# 0: 640x544 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 544)
# Image: night (1495).jpg, GT: 21Y97838, Pred: 21Y97838, Match: True, Time: 0.0172s
#
# 0: 640x384 1 کل ناحیه پلاک, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_16065.jpg, GT: 86J52555, Pred: 88J5758, Match: False, Time: 0.0236s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_08205.jpg, GT: 67Ṣ68234, Pred: 67Ṣ68233, Match: False, Time: 0.0258s
#
# 0: 512x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: night (925).jpg, GT: 61M14254, Pred: 61M14254, Match: True, Time: 0.0251s
#
# 0: 640x384 2 کل ناحیه پلاکs, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_04087.jpg, GT: 22H85577, Pred: 22H85577, Match: True, Time: 0.0217s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_16280.jpg, GT: 23T92518, Pred: 23T92518, Match: True, Time: 0.0258s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_00199.jpg, GT: 73T93622, Pred: 73T93622, Match: True, Time: 0.0224s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: night (791).jpg, GT: 84J73599, Pred: 84J73599, Match: True, Time: 0.0171s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_06414.jpg, GT: 48N71238, Pred: 48N71238, Match: True, Time: 0.0220s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.2ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_16146.jpg, GT: 15Ṭ74318, Pred: 15Ṭ74318, Match: True, Time: 0.0257s
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.3ms preprocess, 7.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Skipping day_08326.jpg: No license plate detected.
#
# 0: 640x384 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_16871.jpg, GT: 74V31288, Pred: 74V31288, Match: True, Time: 0.0213s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: night (3712).jpg, GT: 32Y91333, Pred: 32Y91333, Match: True, Time: 0.0245s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_09830.jpg, GT: 37H55877, Pred: 37H55877, Match: True, Time: 0.0288s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# Image: night (778).jpg, GT: 24O67111, Pred: 24O67111, Match: True, Time: 0.0256s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_05886.jpg, GT: 69S25268, Pred: 69S25268, Match: True, Time: 0.0239s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_06993.jpg, GT: 16N38644, Pred: 16N38644, Match: True, Time: 0.0274s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: night (733).jpg, GT: 59L49240, Pred: 59L49240, Match: True, Time: 0.0278s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_15759.jpg, GT: 28T81518, Pred: 28T81518, Match: True, Time: 0.0229s
#
# 0: 640x384 2 کل ناحیه پلاکs, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_12752.jpg, GT: 24L19366, Pred: 24L19366, Match: True, Time: 0.0248s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_00555.jpg, GT: 21S11587, Pred: 21S11587, Match: True, Time: 0.0271s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_15338.jpg, GT: 41M51516, Pred: 41M51516, Match: True, Time: 0.0207s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_02661.jpg, GT: 23H67311, Pred: 23H67311, Match: True, Time: 0.0241s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_00693.jpg, GT: 91Y36763, Pred: 91Y36763, Match: True, Time: 0.0245s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_01774.jpg, GT: 95N52233, Pred: 95N52233, Match: True, Time: 0.0257s
#
# 0: 640x384 2 کل ناحیه پلاکs, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: night (3086).jpg, GT: 35H57257, Pred: 25H57257, Match: False, Time: 0.0217s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_12837.jpg, GT: 56L18210, Pred: 56L1823, Match: False, Time: 0.0222s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_06009.jpg, GT: 74H11538, Pred: 74H11538, Match: True, Time: 0.0241s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_03757.jpg, GT: 91Ṣ62434, Pred: 91Ṣ62434, Match: True, Time: 0.0265s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_12783.jpg, GT: 35V13366, Pred: 35V13366, Match: True, Time: 0.0235s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# ...
#
# 0: 512x640 1 کل ناحیه پلاک, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Image: day_05545.jpg, GT: 54B82799, Pred: 54B82799, Match: True, Time: 0.0179s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_05937.jpg, GT: 94N75968, Pred: 94N75968, Match: True, Time: 0.0238s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_10749.jpg, GT: 87H13944, Pred: 87H13944, Match: True, Time: 0.0265s
#
# 0: 640x384 1 کل ناحیه پلاک, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_07210.jpg, GT: 19V88221, Pred: 19V88221, Match: True, Time: 0.0201s
#
# 0: 640x384 2 کل ناحیه پلاکs, 7.0ms
# Speed: 1.3ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_14686.jpg, GT: 78S21416, Pred: 78S21416, Match: True, Time: 0.0216s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_08866.jpg, GT: 14L92826, Pred: 16L92826, Match: False, Time: 0.0227s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_05233.jpg, GT: 77N84599, Pred: 77N84599, Match: True, Time: 0.0197s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_02659.jpg, GT: 41D27711, Pred: 41D27711, Match: True, Time: 0.0225s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: night (2969).jpg, GT: 79V52491, Pred: 79V52491, Match: True, Time: 0.0235s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_03019.jpg, GT: 43D64568, Pred: 43D64568, Match: True, Time: 0.0283s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_06747.jpg, GT: 38S55368, Pred: 38S55368, Match: True, Time: 0.0246s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_09635.jpg, GT: 57D67724, Pred: 57D67724, Match: True, Time: 0.0269s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_04012.jpg, GT: 71H59538, Pred: 71H59538, Match: True, Time: 0.0252s
#
# 0: 640x640 1 کل ناحیه پلاک, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Image: day_13866.jpg, GT: 21Q79479, Pred: 21Q79479, Match: True, Time: 0.0166s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.2ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_03146.jpg, GT: 14T65833, Pred: 14T65833, Match: True, Time: 0.0232s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_02070.jpg, GT: 95N69644, Pred: 95N69644, Match: True, Time: 0.0272s
#
# 0: 640x448 1 کل ناحیه پلاک, 7.4ms
# Speed: 1.4ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
# Image: night (2078).jpg, GT: 28Q64299, Pred: 98Q24259, Match: False, Time: 0.0155s
#
# 0: 640x480 2 کل ناحیه پلاکs, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_10277.jpg, GT: 45J85399, Pred: 45J85399, Match: True, Time: 0.0246s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.2ms preprocess, 7.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_11845.jpg, GT: 85Ṣ54310, Pred: 85Ṣ54310, Match: True, Time: 0.0254s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_14708.jpg, GT: 14B83916, Pred: 14B82916, Match: False, Time: 0.0225s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_00344.jpg, GT: 59Ṭ36510, Pred: 59Ṭ36510, Match: True, Time: 0.0226s
#
# 0: 512x640 1 کل ناحیه پلاک, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Image: day_05684.jpg, GT: 72Q13477, Pred: 72Q13477, Match: True, Time: 0.0162s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_16564.jpg, GT: 12D61368, Pred: 12D61368, Match: True, Time: 0.0231s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_16916.jpg, GT: 11Y16588, Pred: 11Y16588, Match: True, Time: 0.0270s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_07676.jpg, GT: 78M89424, Pred: 78M89424, Match: True, Time: 0.0299s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_03768.jpg, GT: 52L39355, Pred: 52L39355, Match: True, Time: 0.0266s
#
# 0: 416x640 2 کل ناحیه پلاکs, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# Image: night (1483).jpg, GT: 82D87777, Pred: 82D87777, Match: True, Time: 0.0256s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_05930.jpg, GT: 72B37920, Pred: 72B37920, Match: True, Time: 0.0220s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.4ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_03309.jpg, GT: 32V61621, Pred: 32V61621, Match: True, Time: 0.0144s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.0ms
# Speed: 1.2ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: night (2958).jpg, GT: 26Ṣ94616, Pred: 26Ṣ94616, Match: True, Time: 0.0231s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_15766.jpg, GT: 18Ṭ37418, Pred: 18Ṭ37418, Match: True, Time: 0.0217s
#
# 0: 448x640 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Image: day_06321.jpg, GT: 44Ṭ69744, Pred: 44Ṭ69744, Match: True, Time: 0.0183s
#
# 0: 480x640 2 کل ناحیه پلاکs, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_16673.jpg, GT: 58Ṭ77355, Pred: 58Ṭ77355, Match: True, Time: 0.0245s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_08861.jpg, GT: 57M99511, Pred: 57M99511, Match: True, Time: 0.0222s
#
# 0: 640x576 1 کل ناحیه پلاک, 7.3ms
# Speed: 1.7ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
# Image: day_05655.jpg, GT: 66S71433, Pred: 66S71433, Match: True, Time: 0.0160s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.2ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: night (902).jpg, GT: 36H51725, Pred: 46H51726, Match: False, Time: 0.0255s
#
# 0: 384x640 2 کل ناحیه پلاکs, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_15642.jpg, GT: 53S46828, Pred: 53S46828, Match: True, Time: 0.0220s
#
# 0: 640x480 2 کل ناحیه پلاکs, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_03929.jpg, GT: 96Q62222, Pred: 96Q62222, Match: True, Time: 0.0260s
#
# 0: 640x384 2 کل ناحیه پلاکs, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_13009.jpg, GT: 12V64299, Pred: 12V64299, Match: True, Time: 0.0216s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_14463.jpg, GT: 14M21116, Pred: 14M21116, Match: True, Time: 0.0219s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_05771.jpg, GT: 95Q85310, Pred: 95Q85310, Match: True, Time: 0.0249s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.4ms
# Speed: 1.2ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_16832.jpg, GT: 56S46955, Pred: 56S46955, Match: True, Time: 0.0268s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_16440.jpg, GT: 85Ṭ21218, Pred: 85Ṭ21218, Match: True, Time: 0.0219s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.2ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_04647.jpg, GT: 18J25336, Pred: 18J25336, Match: True, Time: 0.0205s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Image: night (3847).jpg, GT: 81S46216, Pred: 41S46216, Match: False, Time: 0.0220s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_14315.jpg, GT: 45Q85216, Pred: 45Q85216, Match: True, Time: 0.0226s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_06112.jpg, GT: 71H83638, Pred: 71H83638, Match: True, Time: 0.0228s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_16021.jpg, GT: 57Q43561, Pred: 57Q43561, Match: True, Time: 0.0282s
#
# 0: 640x640 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Image: day_05466.jpg, GT: 95B88110, Pred: 95B88110, Match: True, Time: 0.0154s
#
# 0: 640x640 1 کل ناحیه پلاک, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Image: day_00338.jpg, GT: 88H38243, Pred: 88H38243, Match: True, Time: 0.0164s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 0.9ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_15134.jpg, GT: 36Ṣ85716, Pred: 36SṢ85716, Match: False, Time: 0.0201s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_07494.jpg, GT: 24V37634, Pred: 24V37634, Match: True, Time: 0.0262s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.5ms
# Speed: 0.9ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_02154.jpg, GT: 83J72222, Pred: 83J72232, Match: False, Time: 0.0212s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_11513.jpg, GT: 27M39388, Pred: 27M39388, Match: True, Time: 0.0245s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_03714.jpg, GT: 51B11120, Pred: 51B11120, Match: True, Time: 0.0263s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Image: day_12406.jpg, GT: 48V69288, Pred: 48V69288, Match: True, Time: 0.0197s
#
# 0: 384x640 3 کل ناحیه پلاکs, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_13246.jpg, GT: 87B79188, Pred: 87B79188, Match: True, Time: 0.0219s
#
# 0: 640x640 1 کل ناحیه پلاک, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Image: night (4062).jpg, GT: 27V95811, Pred: 27V95811, Match: True, Time: 0.0281s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Image: night (4106).jpg, GT: 14Ṣ52618, Pred: 14Ṣ52618, Match: True, Time: 0.0272s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: night (2091).jpg, GT: 97S24299, Pred: 97S24299, Match: True, Time: 0.0259s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Image: night (1052).jpg, GT: 79B36398, Pred: 79B36398, Match: True, Time: 0.0224s
#
# 0: 640x640 2 کل ناحیه پلاکs, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Image: day_00260.jpg, GT: 41S61631, Pred: 41S61631, Match: True, Time: 0.0161s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: night (2259).jpg, GT: 41H77168, Pred: 41H77168, Match: True, Time: 0.0233s
#
# 0: 640x384 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Image: night (3003).jpg, GT: 48L79616, Pred: 48L79616, Match: True, Time: 0.0225s
#
# 0: 384x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.2ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Image: day_12711.jpg, GT: 49M67511, Pred: 49M67511, Match: True, Time: 0.0222s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_02243.jpg, GT: 73H62736, Pred: 73H62736, Match: True, Time: 0.0218s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_10044.jpg, GT: 31N49510, Pred: 31N49510, Match: True, Time: 0.0262s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_03403.jpg, GT: 38Q34841, Pred: 38Q34841, Match: True, Time: 0.0268s
#
# 0: 480x640 1 کل ناحیه پلاک, 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: day_06888.jpg, GT: 23J57168, Pred: 23J57168, Match: True, Time: 0.0309s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_01737.jpg, GT: 93Q23842, Pred: 93Q23842, Match: True, Time: 0.0210s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.3ms
# Speed: 1.2ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: night (1019).jpg, GT: 18J85320, Pred: 18J85320, Match: True, Time: 0.0233s
#
# 0: 480x640 3 کل ناحیه پلاکs, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Image: night (4029).jpg, GT: 93Ṭ87516, Pred: 93Ṭ87516, Match: True, Time: 0.0249s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.8ms
# Speed: 1.2ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_11265.jpg, GT: 32Ṭ29999, Pred: 32Ṭ29999, Match: True, Time: 0.0258s
#
# 0: 640x480 2 کل ناحیه پلاکs, 7.3ms
# Speed: 1.7ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_02622.jpg, GT: 35M84724, Pred: 35M84724, Match: True, Time: 0.0259s
#
# 0: 640x480 1 کل ناحیه پلاک, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Image: day_10425.jpg, GT: 18D39966, Pred: 18D39966, Match: True, Time: 0.0244s
# Accuracy on filtered data: 86.18%
# Average inference time per image: 0.0228s
# Results saved to 'filtered_inference_results.csv'
# Average inference time per image: 0.0228s
